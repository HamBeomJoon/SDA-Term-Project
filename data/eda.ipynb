# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings("ignore")

# %%
df_raw=pd.read_csv("지역별_상품군별_해외직접판매액.csv")

# %%
df_raw
# Out:
#     지역별(1) 지역별(2) 지역별(3)     상품군별(1) 상품군별(2) 판매유형별(1) 2019.1/4 2019.2/4  \
# 0       합계     소계     소계          합계      소계        계  1251122  1345723
# 1       합계     소계     소계          합계      소계      면세점  1070693  1157158
# 2       합계     소계     소계          합계      소계   면세점 이외   180429   188565
# 3       합계     소계     소계  컴퓨터 및 주변기기      소계        계     3702     4038
# 4       합계     소계     소계  컴퓨터 및 주변기기      소계      면세점        2        0
# ..     ...    ...    ...         ...     ...      ...      ...      ...
# 964     기타     소계     소계    생활·자동차용품      소계      면세점        0        0
# 965     기타     소계     소계    생활·자동차용품      소계   면세점 이외      465      488
# 966     기타     소계     소계         기 타      소계        계      711      689
# 967     기타     소계     소계         기 타      소계      면세점        0        1
# 968     기타     소계     소계         기 타      소계   면세점 이외      711      688
#
#     2019.3/4 2019.4/4  ... 2021.2/4 2021.3/4 2021.4/4 2022.1/4 2022.2/4  \
# ...

# %%
df_raw.shape
# Out:
# (969, 25)

# %%
df_raw.columns
# Out:
# Index(['지역별(1)', '지역별(2)', '지역별(3)', '상품군별(1)', '상품군별(2)', '판매유형별(1)',
#        '2019.1/4', '2019.2/4', '2019.3/4', '2019.4/4', '2020.1/4', '2020.2/4',
#        '2020.3/4', '2020.4/4', '2021.1/4', '2021.2/4', '2021.3/4', '2021.4/4',
#        '2022.1/4', '2022.2/4', '2022.3/4', '2022.4/4', '2023.1/4', '2023.2/4',
#        '2023.3/4 p)'],
#       dtype='object')

# %%
unique_elements =df_raw['지역별(1)'].unique()
print(unique_elements)
unique_elements =df_raw['지역별(2)'].unique()
print(unique_elements)
unique_elements =df_raw['지역별(3)'].unique()
print(unique_elements)
# Out:
# ['합계' '아시아' '북미' '유럽' '대양주' '중남미' '아프리카' '기타']
# ['소계' '중국' '일본' '아세안' '중동' '기타 아시아' '미국' '캐나다' '유럽연합+영국' '기타 유럽']
# ['소계' '유럽연합' '영국']

# %%
unique_elements =df_raw['상품군별(1)'].unique()
print(unique_elements)
unique_elements =df_raw['상품군별(2)'].unique()
print(unique_elements)
unique_elements =df_raw['판매유형별(1)'].unique()
print(unique_elements)
# Out:
# ['합계' '컴퓨터 및 주변기기' '가전·전자·통신기기' '소프트웨어' '서 적' '사무·문구' '음반·비디오·악기'
#  '의류 및 패션 관련 상품' '스포츠·레저용품' '화장품' '아동·유아용품' '음·식료품' '농축수산물' '생활·자동차용품'
#  '기 타']
# ['소계' '가전·전자' '통신기기']
# ['계' '면세점' '면세점 이외']

# %%
delet_col=['지역별(1)','지역별(3)','상품군별(2)']
df_raw.drop(delet_col, axis=1, inplace=True)

# %%
df_raw.head()
# Out:
#   지역별(2)     상품군별(1) 판매유형별(1) 2019.1/4 2019.2/4 2019.3/4 2019.4/4 2020.1/4  \
# 0     소계          합계        계  1251122  1345723  1526135  1881628  1531212
# 1     소계          합계      면세점  1070693  1157158  1336372  1655635  1297490
# 2     소계          합계   면세점 이외   180429   188565   189763   225993   233722
# 3     소계  컴퓨터 및 주변기기        계     3702     4038     3670     3827     4142
# 4     소계  컴퓨터 및 주변기기      면세점        2        0        1       70      113
#
#   2020.2/4 2020.3/4  ... 2021.2/4 2021.3/4 2021.4/4 2022.1/4 2022.2/4  \
# 0  1290332  1656729  ...  1222986  1034913   926718   567581   505954
# 1  1051987  1410967  ...   974415   795824   681168   363520   300602
# 2   238345   245762  ...   248571   239089   245550   204061   205352
# 3     3814     7722  ...     4450     3612     2707     2449     2867
# 4        0     3497  ...        0        0        0        0        0
#
#   2022.3/4 2022.4/4 2023.1/4 2023.2/4 2023.3/4 p)
# ...

# %%
df =df_raw.melt(id_vars=["지역별(2)",'상품군별(1)','판매유형별(1)'], var_name="기간", value_name="백만원")
df.shape
# Out:
# (18411, 5)

# %%
df.head()
# Out:
#   지역별(2)     상품군별(1) 판매유형별(1)        기간      백만원
# 0     소계          합계        계  2019.1/4  1251122
# 1     소계          합계      면세점  2019.1/4  1070693
# 2     소계          합계   면세점 이외  2019.1/4   180429
# 3     소계  컴퓨터 및 주변기기        계  2019.1/4     3702
# 4     소계  컴퓨터 및 주변기기      면세점  2019.1/4        2

# %%
df['연도']=df["기간"].map(lambda x: int(x.split('.')[0]))
df.head()
# Out:
#   지역별(2)     상품군별(1) 판매유형별(1)        기간      백만원    연도
# 0     소계          합계        계  2019.1/4  1251122  2019
# 1     소계          합계      면세점  2019.1/4  1070693  2019
# 2     소계          합계   면세점 이외  2019.1/4   180429  2019
# 3     소계  컴퓨터 및 주변기기        계  2019.1/4     3702  2019
# 4     소계  컴퓨터 및 주변기기      면세점  2019.1/4        2  2019

# %%
df["분기"] = df["기간"].map(lambda x: int(x.split('.')[1].split('/')[0]))
df.head()
# Out:
#   지역별(2)     상품군별(1) 판매유형별(1)        기간      백만원    연도  분기
# 0     소계          합계        계  2019.1/4  1251122  2019   1
# 1     소계          합계      면세점  2019.1/4  1070693  2019   1
# 2     소계          합계   면세점 이외  2019.1/4   180429  2019   1
# 3     소계  컴퓨터 및 주변기기        계  2019.1/4     3702  2019   1
# 4     소계  컴퓨터 및 주변기기      면세점  2019.1/4        2  2019   1

# %%
df["백만원"]=df['백만원'].replace("-",np.nan).astype(float)

# %%
df = df[(df["지역별(2)"]!="소계") & (df["상품군별(1)"] != "합계")].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10032 entries, 105 to 18206
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역별(2)    10032 non-null  object
#  1   상품군별(1)   10032 non-null  object
#  2   판매유형별(1)  10032 non-null  object
#  3   기간        10032 non-null  object
#  4   백만원       5616 non-null   float64
#  5   연도        10032 non-null  int64
#  6   분기        10032 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 627.0+ KB

# %%
df.isnull().sum()
# Out:
# 지역별(2)         0
# 상품군별(1)        0
# 판매유형별(1)       0
# 기간             0
# 백만원         4416
# 연도             0
# 분기             0
# dtype: int64

# %%
df_total= df[df["판매유형별(1)"]=="계"].copy()
df_total # 전처리 끝
# Out:
#       지역별(2)     상품군별(1) 판매유형별(1)           기간      백만원    연도  분기
# 105       중국  컴퓨터 및 주변기기        계     2019.1/4     31.0  2019   1
# 108       중국  가전·전자·통신기기        계     2019.1/4  13657.0  2019   1
# 111       중국  가전·전자·통신기기        계     2019.1/4      NaN  2019   1
# 114       중국  가전·전자·통신기기        계     2019.1/4      NaN  2019   1
# 117       중국       소프트웨어        계     2019.1/4      6.0  2019   1
# ...      ...         ...      ...          ...      ...   ...  ..
# 18192  기타 유럽     아동·유아용품        계  2023.3/4 p)     56.0  2023   3
# 18195  기타 유럽       음·식료품        계  2023.3/4 p)     11.0  2023   3
# 18198  기타 유럽       농축수산물        계  2023.3/4 p)      0.0  2023   3
# 18201  기타 유럽    생활·자동차용품        계  2023.3/4 p)      1.0  2023   3
# 18204  기타 유럽         기 타        계  2023.3/4 p)      8.0  2023   3
#
# [3344 rows x 7 columns]

# %%
sns.set(font="Malgun Gothic")
# %config InlineBackend.figure_format='retina'

# %%
sns.lineplot(data=df_total, x="연도",y='백만원')
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
sns.lineplot(data=df_total, x='연도',y="백만원",hue="상품군별(1)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.relplot(data=df_total, x="연도",y="백만원", hue="상품군별(1)", kind='line', col="상품군별(1)",col_wrap=4)

# %%
df
# Out:
#       지역별(2)     상품군별(1) 판매유형별(1)           기간      백만원    연도  분기
# 105       중국  컴퓨터 및 주변기기        계     2019.1/4     31.0  2019   1
# 106       중국  컴퓨터 및 주변기기      면세점     2019.1/4      2.0  2019   1
# 107       중국  컴퓨터 및 주변기기   면세점 이외     2019.1/4     29.0  2019   1
# 108       중국  가전·전자·통신기기        계     2019.1/4  13657.0  2019   1
# 109       중국  가전·전자·통신기기      면세점     2019.1/4  13347.0  2019   1
# ...      ...         ...      ...          ...      ...   ...  ..
# 18202  기타 유럽    생활·자동차용품      면세점  2023.3/4 p)      0.0  2023   3
# 18203  기타 유럽    생활·자동차용품   면세점 이외  2023.3/4 p)      1.0  2023   3
# 18204  기타 유럽         기 타        계  2023.3/4 p)      8.0  2023   3
# 18205  기타 유럽         기 타      면세점  2023.3/4 p)      0.0  2023   3
# 18206  기타 유럽         기 타   면세점 이외  2023.3/4 p)      8.0  2023   3
#
# [10032 rows x 7 columns]

# %%
# 화장품

# %%
df_cosmetic = df_total[df_total["상품군별(1)"] == "화장품"].copy()
df_cosmetic['상품군별(1)'].unique()
# Out:
# array(['화장품'], dtype=object)

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data= df_cosmetic, x="연도", y='백만원', hue ='분기')
# Out:
# <Axes: xlabel='연도', ylabel='백만원'>

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_cosmetic, x="기간", y='백만원')
# Out:
# <Axes: xlabel='기간', ylabel='백만원'>

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_cosmetic, x="기간", y='백만원', hue="지역별(2)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_cosmetic[df_cosmetic["지역별(2)"]!="중국"], x="기간", y='백만원', hue="지역별(2)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#의류 및 패션 관련 상품

# %%
df_fashion= df_total[(df_total['상품군별(1)'] == "의류 및 패션 관련 상품") & (df_total['판매유형별(1)']=='계')].copy()

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_fashion, x= '기간', y= '백만원',hue='지역별(2)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_fashion, x="기간", y='백만원')
plt.title("패션관련 수출액 추이")
# Out:
# Text(0.5, 1.0, '패션관련 수출액 추이')

# %%
#음반·비디오·악기

# %%
df_music = df_total[df_total["상품군별(1)"] == "음반·비디오·악기"].copy()
df_music['상품군별(1)'].unique()
# Out:
# array(['음반·비디오·악기'], dtype=object)

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data= df_music, x="연도", y='백만원', hue ='분기')
plt.title("연도, 분기별 수출액 추이")
# Out:
# Text(0.5, 1.0, '연도, 분기별 수출액 추이')

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_music, x="기간", y='백만원')
plt.title("음악관련 수출액 추이")
# Out:
# Text(0.5, 1.0, '음악관련 수출액 추이')

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_music, x="기간", y='백만원', hue="지역별(2)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("음악 관련 나라별 수출액 추이")
# Out:
# Text(0.5, 1.0, '음악 관련 나라별 수출액 추이')

# %%
plt.figure(figsize =(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_music[df_music["지역별(2)"]!="중국"], x="기간", y='백만원', hue="지역별(2)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("중국 제외")
# Out:
# Text(0.5, 1.0, '중국 제외')

# %%
df_fashion= df_total[(df_total['상품군별(1)'] == "음반·비디오·악기") & (df_total['판매유형별(1)']=='계')].copy()

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation =30)
sns.lineplot(data=df_music, x= '기간', y= '백만원',hue='지역별(2)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("음반 비디오 악기 등 나라별 수출액 추이")
# Out:
# Text(0.5, 1.0, '음반 비디오 악기 등 나라별 수출액 추이')

# %%
result=df_music.pivot_table(index="지역별(2)",columns="연도",values="백만원", aggfunc="sum")

# %%
plt.figure(figsize=(10,5))
sns.heatmap(result, cmap='Blues', annot=True,fmt=".0f")
plt.title("국가별 음악 관련 상품 판매량 상관관계")
plt.ylabel("국가별")
# Out:
# Text(90.24999999999999, 0.5, '국가별')

# %%
#전체데이터

# %%
sns.barplot(data=df_total, x= "연도", y="백만원")
plt.title("연도별 수출액 추이")
# Out:
# Text(0.5, 1.0, '연도별 수출액 추이')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_total, x="연도", y= "백만원",hue="지역별(2)")
plt.title("국가별 수출액 추이")
# Out:
# Text(0.5, 1.0, '국가별 수출액 추이')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_total, x="연도", y= "백만원",hue="상품군별(1)")
plt.legend(bbox_to_anchor=(1.05,1), loc= 2, borderaxespad=0.)
plt.title("상품군별 수출액 추이")
# Out:
# Text(0.5, 1.0, '상품군별 수출액 추이')

# %%
df_total = df_total[df_total['지역별(2)']=='중국'].copy()
df_total
# Out:
#       지역별(2)     상품군별(1) 판매유형별(1)           기간      백만원    연도  분기
# 105       중국  컴퓨터 및 주변기기        계     2019.1/4     31.0  2019   1
# 108       중국  가전·전자·통신기기        계     2019.1/4  13657.0  2019   1
# 111       중국  가전·전자·통신기기        계     2019.1/4      NaN  2019   1
# 114       중국  가전·전자·통신기기        계     2019.1/4      NaN  2019   1
# 117       중국       소프트웨어        계     2019.1/4      6.0  2019   1
# ...      ...         ...      ...          ...      ...   ...  ..
# 17580     중국     아동·유아용품        계  2023.3/4 p)    888.0  2023   3
# 17583     중국       음·식료품        계  2023.3/4 p)   2580.0  2023   3
# 17586     중국       농축수산물        계  2023.3/4 p)      2.0  2023   3
# 17589     중국    생활·자동차용품        계  2023.3/4 p)    315.0  2023   3
# 17592     중국         기 타        계  2023.3/4 p)   2249.0  2023   3
#
# [304 rows x 7 columns]

# %%
df_total= df_total[(df_total['상품군별(1)'] == "의류 및 패션 관련 상품") | (df_total['상품군별(1)'] == "화장품")]

# %%
result_df = df_total.groupby(['연도', '분기'])['백만원'].sum().reset_index()
result_df
# Out:
#       연도  분기        백만원
# 0   2019   1  1024492.0
# 1   2019   2  1103035.0
# 2   2019   3  1277763.0
# 3   2019   4  1621618.0
# 4   2020   1  1278680.0
# 5   2020   2  1059043.0
# 6   2020   3  1409906.0
# 7   2020   4  1254072.0
# 8   2021   1   981479.0
# 9   2021   2   975129.0
# 10  2021   3   804569.0
# 11  2021   4   697634.0
# 12  2022   1   330685.0
# 13  2022   2   305769.0
# 14  2022   3   218298.0
# 15  2022   4   159688.0
# 16  2023   1   116414.0
# 17  2023   2   283891.0
# 18  2023   3   272830.0

# %%
result_df['연도'] = pd.to_numeric(result_df['연도'])
china_filtered_df = result_df[result_df['연도'] >= 2020]

# 결과 출력
china_filtered_df
# Out:
#       연도  분기        백만원
# 4   2020   1  1278680.0
# 5   2020   2  1059043.0
# 6   2020   3  1409906.0
# 7   2020   4  1254072.0
# 8   2021   1   981479.0
# 9   2021   2   975129.0
# 10  2021   3   804569.0
# 11  2021   4   697634.0
# 12  2022   1   330685.0
# 13  2022   2   305769.0
# 14  2022   3   218298.0
# 15  2022   4   159688.0
# 16  2023   1   116414.0
# 17  2023   2   283891.0
# 18  2023   3   272830.0

# %%
plt.figure(figsize=(10, 6))
for year in result_df['연도'].unique():
    year_data = result_df[result_df['연도'] == year]
    plt.plot(year_data['분기'], year_data['백만원'], label=str(year))

# 그래프 속성 설정
plt.title('연도별 분기별 백만원 그래프')
plt.xlabel('분기')
plt.ylabel('백만원')
plt.legend()
plt.grid(True)

# 그래프 출력
plt.show()
